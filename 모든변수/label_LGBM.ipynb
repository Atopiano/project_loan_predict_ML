# %% [markdown]
# # LGBM 라벨인코딩 모든 변수

# %%
# 필요한 sklearn import 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# train data set
loan_train = pd.read_csv('../label_loan_train.csv')

# %%
# train data set의 컬럼 확인 
loan_train.columns
# Out:
# Index(['Loan Amount', 'Funded Amount', 'Funded Amount Investor', 'Term',
#        'Interest Rate', 'Grade', 'Sub Grade', 'Home Ownership',
#        'Employment Duration', 'Verification Status', 'Loan Title',
#        'Debit to Income', 'Delinquency - two years', 'Inquires - six months',
#        'Open Account', 'Public Record', 'Revolving Balance',
#        'Revolving Utilities', 'Total Accounts', 'Initial List Status',
#        'Total Received Interest', 'Total Received Late Fee', 'Recoveries',
#        'Collection Recovery Fee', 'Collection 12 months Medical',
#        'Application Type', 'Last week Pay', 'Accounts Delinquent',
#        'Total Collection Amount', 'Total Current Balance',
#        'Total Revolving Credit Limit', 'Loan Status'],
#       dtype='object')

# %%
# 독립변수와 종속변수 선택하기
X = loan_train.drop("Loan Status", axis = 1)
y = loan_train["Loan Status"]

# %%
# 타겟의 비대칭 데이터 문제를 해결하기 위하여 SMOTETomek를 사용

#데이터 클래스 비율이 너무 차이가 나면(highly-imbalanced data) 
#단순히 우세한 클래스를 택하는 모형의 정확도가 높아지므로 모형의 성능판별이 어려워진다. 
#즉, 정확도(accuracy)가 높아도 데이터 갯수가 적은 클래스의 재현율(recall-rate)이 급격히 작아지는 현상이 발생할 수 있다.

from imblearn.combine import SMOTETomek
from collections import Counter
Counter(y)

os=SMOTETomek(sampling_strategy='auto',random_state = 20)
X_train_ns,y_train_ns=os.fit_resample(X,y)
print("The number of classes before fit {}".format(Counter(y)))
print("The number of classes after fit {}".format(Counter(y_train_ns)))
# Out:
# The number of classes before fit Counter({0: 61222, 1: 1625})
# The number of classes after fit Counter({0: 61196, 1: 61196})

# %%
# 데이터 셋 분할
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_train_ns, y_train_ns, test_size = 0.25, random_state = 20, stratify = y_train_ns)
y_train_ns.value_counts(True), y_test.value_counts(True)
# Out:
# (0    0.5
#  1    0.5
#  Name: Loan Status, dtype: float64,
#  0    0.5
#  1    0.5
#  Name: Loan Status, dtype: float64)

# %% [markdown]
# # LGBM 예측 및 성능지표

# %%
from lightgbm import LGBMClassifier

lgbm = LGBMClassifier(n_estimators=400, random_state=20)

lgbm.fit(X_train, y_train, early_stopping_rounds=100, eval_metric='logloss',
         eval_set = [(X_test,y_test)], verbose=True)
# Out:
# [1]	valid_0's binary_logloss: 0.63681
# [2]	valid_0's binary_logloss: 0.5906
# [3]	valid_0's binary_logloss: 0.551993
# [4]	valid_0's binary_logloss: 0.518694
# [5]	valid_0's binary_logloss: 0.491187
# [6]	valid_0's binary_logloss: 0.465153
# [7]	valid_0's binary_logloss: 0.444552
# [8]	valid_0's binary_logloss: 0.424628
# [9]	valid_0's binary_logloss: 0.40966
# [10]	valid_0's binary_logloss: 0.394475
# [11]	valid_0's binary_logloss: 0.380988
# [12]	valid_0's binary_logloss: 0.37046
# [13]	valid_0's binary_logloss: 0.357882
# [14]	valid_0's binary_logloss: 0.348022
# [15]	valid_0's binary_logloss: 0.338123
# [16]	valid_0's binary_logloss: 0.330756
# [17]	valid_0's binary_logloss: 0.324744
# [18]	valid_0's binary_logloss: 0.316679
# [19]	valid_0's binary_logloss: 0.310071
# [20]	valid_0's binary_logloss: 0.30525
# [21]	valid_0's binary_logloss: 0.297446
# [22]	valid_0's binary_logloss: 0.291865
# [23]	valid_0's binary_logloss: 0.288382
# [24]	valid_0's binary_logloss: 0.282857
# [25]	valid_0's binary_logloss: 0.277593
# [26]	valid_0's binary_logloss: 0.273749
# [27]	valid_0's binary_logloss: 0.270331
# [28]	valid_0's binary_logloss: 0.266981
# [29]	valid_0's binary_logloss: 0.262641
# [30]	valid_0's binary_logloss: 0.259763
# [31]	valid_0's binary_logloss: 0.257328
# [32]	valid_0's binary_logloss: 0.254568
# [33]	valid_0's binary_logloss: 0.251117
# [34]	valid_0's binary_logloss: 0.248292
# [35]	valid_0's binary_logloss: 0.245864
# [36]	valid_0's binary_logloss: 0.24381
# [37]	valid_0's binary_logloss: 0.241663
# [38]	valid_0's binary_logloss: 0.239532
# [39]	valid_0's binary_logloss: 0.236804
# [40]	valid_0's binary_logloss: 0.234443
# [41]	valid_0's binary_logloss: 0.232773
# [42]	valid_0's binary_logloss: 0.231309
# [43]	valid_0's binary_logloss: 0.229782
# [44]	valid_0's binary_logloss: 0.228281
# [45]	valid_0's binary_logloss: 0.22639
# [46]	valid_0's binary_logloss: 0.224933
# [47]	valid_0's binary_logloss: 0.223155
# [48]	valid_0's binary_logloss: 0.221789
# [49]	valid_0's binary_logloss: 0.220535
# [50]	valid_0's binary_logloss: 0.219075
# [51]	valid_0's binary_logloss: 0.217702
# [52]	valid_0's binary_logloss: 0.216277
# [53]	valid_0's binary_logloss: 0.21512
# [54]	valid_0's binary_logloss: 0.214019
# [55]	valid_0's binary_logloss: 0.212761
# [56]	valid_0's binary_logloss: 0.211801
# [57]	valid_0's binary_logloss: 0.210567
# [58]	valid_0's binary_logloss: 0.20947
# [59]	valid_0's binary_logloss: 0.20853
# [60]	valid_0's binary_logloss: 0.207391
# [61]	valid_0's binary_logloss: 0.2065
# [62]	valid_0's binary_logloss: 0.205527
# [63]	valid_0's binary_logloss: 0.204513
# [64]	valid_0's binary_logloss: 0.20363
# [65]	valid_0's binary_logloss: 0.202659
# [66]	valid_0's binary_logloss: 0.2019
# [67]	valid_0's binary_logloss: 0.200985
# [68]	valid_0's binary_logloss: 0.200201
# [69]	valid_0's binary_logloss: 0.199212
# [70]	valid_0's binary_logloss: 0.198412
# [71]	valid_0's binary_logloss: 0.197535
# [72]	valid_0's binary_logloss: 0.196999
# [73]	valid_0's binary_logloss: 0.196213
# [74]	valid_0's binary_logloss: 0.195555
# [75]	valid_0's binary_logloss: 0.194957
# [76]	valid_0's binary_logloss: 0.19424
# [77]	valid_0's binary_logloss: 0.193535
# [78]	valid_0's binary_logloss: 0.192748
# [79]	valid_0's binary_logloss: 0.191951
# [80]	valid_0's binary_logloss: 0.191399
# [81]	valid_0's binary_logloss: 0.190779
# [82]	valid_0's binary_logloss: 0.190197
# [83]	valid_0's binary_logloss: 0.189608
# [84]	valid_0's binary_logloss: 0.189089
# [85]	valid_0's binary_logloss: 0.188322
# [86]	valid_0's binary_logloss: 0.187893
# [87]	valid_0's binary_logloss: 0.187407
# [88]	valid_0's binary_logloss: 0.186734
# [89]	valid_0's binary_logloss: 0.186179
# [90]	valid_0's binary_logloss: 0.18559
# [91]	valid_0's binary_logloss: 0.184983
# [92]	valid_0's binary_logloss: 0.184412
# [93]	valid_0's binary_logloss: 0.183709
# [94]	valid_0's binary_logloss: 0.183291
# [95]	valid_0's binary_logloss: 0.18282
# [96]	valid_0's binary_logloss: 0.182241
# [97]	valid_0's binary_logloss: 0.181531
# [98]	valid_0's binary_logloss: 0.180998
# [99]	valid_0's binary_logloss: 0.18049
# [100]	valid_0's binary_logloss: 0.179984
# [101]	valid_0's binary_logloss: 0.179508
# [102]	valid_0's binary_logloss: 0.178998
# [103]	valid_0's binary_logloss: 0.178487
# [104]	valid_0's binary_logloss: 0.178057
# [105]	valid_0's binary_logloss: 0.177631
# [106]	valid_0's binary_logloss: 0.177332
# [107]	valid_0's binary_logloss: 0.176738
# [108]	valid_0's binary_logloss: 0.176217
# [109]	valid_0's binary_logloss: 0.175845
# [110]	valid_0's binary_logloss: 0.175216
# [111]	valid_0's binary_logloss: 0.174874
# [112]	valid_0's binary_logloss: 0.174384
# [113]	valid_0's binary_logloss: 0.17405
# [114]	valid_0's binary_logloss: 0.173697
# [115]	valid_0's binary_logloss: 0.173372
# [116]	valid_0's binary_logloss: 0.17285
# [117]	valid_0's binary_logloss: 0.172334
# [118]	valid_0's binary_logloss: 0.171901
# [119]	valid_0's binary_logloss: 0.171566
# [120]	valid_0's binary_logloss: 0.171148
# [121]	valid_0's binary_logloss: 0.170668
# [122]	valid_0's binary_logloss: 0.170267
# [123]	valid_0's binary_logloss: 0.169917
# [124]	valid_0's binary_logloss: 0.169464
# [125]	valid_0's binary_logloss: 0.169047
# [126]	valid_0's binary_logloss: 0.168709
# [127]	valid_0's binary_logloss: 0.168348
# [128]	valid_0's binary_logloss: 0.168099
# [129]	valid_0's binary_logloss: 0.167659
# [130]	valid_0's binary_logloss: 0.167413
# [131]	valid_0's binary_logloss: 0.166992
# [132]	valid_0's binary_logloss: 0.166682
# [133]	valid_0's binary_logloss: 0.166303
# [134]	valid_0's binary_logloss: 0.165706
# [135]	valid_0's binary_logloss: 0.165296
# [136]	valid_0's binary_logloss: 0.164855
# [137]	valid_0's binary_logloss: 0.164546
# [138]	valid_0's binary_logloss: 0.164117
# [139]	valid_0's binary_logloss: 0.163824
# [140]	valid_0's binary_logloss: 0.163398
# [141]	valid_0's binary_logloss: 0.163073
# [142]	valid_0's binary_logloss: 0.162534
# [143]	valid_0's binary_logloss: 0.162232
# [144]	valid_0's binary_logloss: 0.161864
# [145]	valid_0's binary_logloss: 0.161488
# [146]	valid_0's binary_logloss: 0.161174
# [147]	valid_0's binary_logloss: 0.160848
# [148]	valid_0's binary_logloss: 0.160653
# [149]	valid_0's binary_logloss: 0.160249
# [150]	valid_0's binary_logloss: 0.159818
# [151]	valid_0's binary_logloss: 0.159599
# [152]	valid_0's binary_logloss: 0.159372
# [153]	valid_0's binary_logloss: 0.159032
# [154]	valid_0's binary_logloss: 0.158696
# [155]	valid_0's binary_logloss: 0.158361
# [156]	valid_0's binary_logloss: 0.158024
# [157]	valid_0's binary_logloss: 0.157726
# [158]	valid_0's binary_logloss: 0.157329
# [159]	valid_0's binary_logloss: 0.157037
# [160]	valid_0's binary_logloss: 0.156566
# [161]	valid_0's binary_logloss: 0.156298
# [162]	valid_0's binary_logloss: 0.155923
# [163]	valid_0's binary_logloss: 0.155559
# [164]	valid_0's binary_logloss: 0.155187
# [165]	valid_0's binary_logloss: 0.154738
# [166]	valid_0's binary_logloss: 0.15429
# [167]	valid_0's binary_logloss: 0.153986
# [168]	valid_0's binary_logloss: 0.153689
# [169]	valid_0's binary_logloss: 0.153373
# [170]	valid_0's binary_logloss: 0.153031
# [171]	valid_0's binary_logloss: 0.15268
# [172]	valid_0's binary_logloss: 0.152386
# [173]	valid_0's binary_logloss: 0.152091
# [174]	valid_0's binary_logloss: 0.151818
# [175]	valid_0's binary_logloss: 0.151422
# [176]	valid_0's binary_logloss: 0.151129
# [177]	valid_0's binary_logloss: 0.150821
# [178]	valid_0's binary_logloss: 0.150536
# [179]	valid_0's binary_logloss: 0.150143
# [180]	valid_0's binary_logloss: 0.149964
# [181]	valid_0's binary_logloss: 0.14964
# [182]	valid_0's binary_logloss: 0.149426
# [183]	valid_0's binary_logloss: 0.149038
# [184]	valid_0's binary_logloss: 0.148716
# [185]	valid_0's binary_logloss: 0.148456
# [186]	valid_0's binary_logloss: 0.148205
# [187]	valid_0's binary_logloss: 0.147885
# [188]	valid_0's binary_logloss: 0.14761
# [189]	valid_0's binary_logloss: 0.14735
# [190]	valid_0's binary_logloss: 0.147093
# [191]	valid_0's binary_logloss: 0.146887
# [192]	valid_0's binary_logloss: 0.146588
# [193]	valid_0's binary_logloss: 0.14626
# [194]	valid_0's binary_logloss: 0.146018
# [195]	valid_0's binary_logloss: 0.145757
# [196]	valid_0's binary_logloss: 0.145471
# [197]	valid_0's binary_logloss: 0.145089
# [198]	valid_0's binary_logloss: 0.144835
# [199]	valid_0's binary_logloss: 0.144516
# [200]	valid_0's binary_logloss: 0.144279
# [201]	valid_0's binary_logloss: 0.143989
# [202]	valid_0's binary_logloss: 0.143813
# [203]	valid_0's binary_logloss: 0.143517
# [204]	valid_0's binary_logloss: 0.143279
# [205]	valid_0's binary_logloss: 0.143046
# [206]	valid_0's binary_logloss: 0.142799
# [207]	valid_0's binary_logloss: 0.142475
# [208]	valid_0's binary_logloss: 0.142232
# [209]	valid_0's binary_logloss: 0.141956
# [210]	valid_0's binary_logloss: 0.141771
# [211]	valid_0's binary_logloss: 0.141616
# [212]	valid_0's binary_logloss: 0.141275
# [213]	valid_0's binary_logloss: 0.141031
# [214]	valid_0's binary_logloss: 0.140779
# [215]	valid_0's binary_logloss: 0.140551
# [216]	valid_0's binary_logloss: 0.140244
# [217]	valid_0's binary_logloss: 0.139995
# [218]	valid_0's binary_logloss: 0.139796
# [219]	valid_0's binary_logloss: 0.139556
# [220]	valid_0's binary_logloss: 0.139361
# [221]	valid_0's binary_logloss: 0.139056
# [222]	valid_0's binary_logloss: 0.138859
# [223]	valid_0's binary_logloss: 0.138629
# [224]	valid_0's binary_logloss: 0.138234
# [225]	valid_0's binary_logloss: 0.13796
# [226]	valid_0's binary_logloss: 0.137725
# [227]	valid_0's binary_logloss: 0.13746
# [228]	valid_0's binary_logloss: 0.137319
# [229]	valid_0's binary_logloss: 0.137097
# [230]	valid_0's binary_logloss: 0.136856
# [231]	valid_0's binary_logloss: 0.136576
# [232]	valid_0's binary_logloss: 0.13629
# [233]	valid_0's binary_logloss: 0.136033
# [234]	valid_0's binary_logloss: 0.135771
# [235]	valid_0's binary_logloss: 0.135479
# [236]	valid_0's binary_logloss: 0.135284
# [237]	valid_0's binary_logloss: 0.135035
# [238]	valid_0's binary_logloss: 0.134787
# [239]	valid_0's binary_logloss: 0.134559
# [240]	valid_0's binary_logloss: 0.134366
# [241]	valid_0's binary_logloss: 0.134186
# [242]	valid_0's binary_logloss: 0.133933
# [243]	valid_0's binary_logloss: 0.133753
# [244]	valid_0's binary_logloss: 0.133603
# [245]	valid_0's binary_logloss: 0.133349
# [246]	valid_0's binary_logloss: 0.133098
# [247]	valid_0's binary_logloss: 0.132929
# [248]	valid_0's binary_logloss: 0.132758
# [249]	valid_0's binary_logloss: 0.132552
# [250]	valid_0's binary_logloss: 0.132275
# [251]	valid_0's binary_logloss: 0.132019
# [252]	valid_0's binary_logloss: 0.131796
# [253]	valid_0's binary_logloss: 0.131525
# [254]	valid_0's binary_logloss: 0.131319
# [255]	valid_0's binary_logloss: 0.131158
# [256]	valid_0's binary_logloss: 0.130909
# [257]	valid_0's binary_logloss: 0.130783
# [258]	valid_0's binary_logloss: 0.130588
# [259]	valid_0's binary_logloss: 0.130348
# [260]	valid_0's binary_logloss: 0.130151
# [261]	valid_0's binary_logloss: 0.129903
# [262]	valid_0's binary_logloss: 0.129726
# [263]	valid_0's binary_logloss: 0.129537
# [264]	valid_0's binary_logloss: 0.129297
# [265]	valid_0's binary_logloss: 0.12917
# [266]	valid_0's binary_logloss: 0.128968
# [267]	valid_0's binary_logloss: 0.128817
# [268]	valid_0's binary_logloss: 0.128543
# [269]	valid_0's binary_logloss: 0.128237
# [270]	valid_0's binary_logloss: 0.128124
# [271]	valid_0's binary_logloss: 0.1279
# [272]	valid_0's binary_logloss: 0.127687
# [273]	valid_0's binary_logloss: 0.127327
# [274]	valid_0's binary_logloss: 0.12717
# [275]	valid_0's binary_logloss: 0.126922
# [276]	valid_0's binary_logloss: 0.126696
# [277]	valid_0's binary_logloss: 0.126551
# [278]	valid_0's binary_logloss: 0.12638
# [279]	valid_0's binary_logloss: 0.126239
# [280]	valid_0's binary_logloss: 0.12608
# [281]	valid_0's binary_logloss: 0.125838
# [282]	valid_0's binary_logloss: 0.125601
# [283]	valid_0's binary_logloss: 0.125397
# [284]	valid_0's binary_logloss: 0.125242
# [285]	valid_0's binary_logloss: 0.12511
# [286]	valid_0's binary_logloss: 0.124904
# [287]	valid_0's binary_logloss: 0.124707
# [288]	valid_0's binary_logloss: 0.124494
# [289]	valid_0's binary_logloss: 0.124319
# [290]	valid_0's binary_logloss: 0.124092
# [291]	valid_0's binary_logloss: 0.123885
# [292]	valid_0's binary_logloss: 0.123655
# [293]	valid_0's binary_logloss: 0.123507
# [294]	valid_0's binary_logloss: 0.123335
# [295]	valid_0's binary_logloss: 0.123164
# [296]	valid_0's binary_logloss: 0.12305
# [297]	valid_0's binary_logloss: 0.122893
# [298]	valid_0's binary_logloss: 0.122647
# [299]	valid_0's binary_logloss: 0.122462
# [300]	valid_0's binary_logloss: 0.122353
# [301]	valid_0's binary_logloss: 0.122087
# [302]	valid_0's binary_logloss: 0.121946
# [303]	valid_0's binary_logloss: 0.121791
# [304]	valid_0's binary_logloss: 0.121604
# [305]	valid_0's binary_logloss: 0.121395
# [306]	valid_0's binary_logloss: 0.121218
# [307]	valid_0's binary_logloss: 0.120966
# [308]	valid_0's binary_logloss: 0.120769
# [309]	valid_0's binary_logloss: 0.12063
# [310]	valid_0's binary_logloss: 0.120481
# [311]	valid_0's binary_logloss: 0.120347
# [312]	valid_0's binary_logloss: 0.120199
# [313]	valid_0's binary_logloss: 0.120056
# [314]	valid_0's binary_logloss: 0.119849
# [315]	valid_0's binary_logloss: 0.119662
# [316]	valid_0's binary_logloss: 0.119498
# [317]	valid_0's binary_logloss: 0.119323
# [318]	valid_0's binary_logloss: 0.119207
# [319]	valid_0's binary_logloss: 0.119045
# [320]	valid_0's binary_logloss: 0.118883
# [321]	valid_0's binary_logloss: 0.118682
# [322]	valid_0's binary_logloss: 0.118472
# [323]	valid_0's binary_logloss: 0.118302
# [324]	valid_0's binary_logloss: 0.118191
# [325]	valid_0's binary_logloss: 0.118056
# [326]	valid_0's binary_logloss: 0.117946
# [327]	valid_0's binary_logloss: 0.117736
# [328]	valid_0's binary_logloss: 0.117691
# [329]	valid_0's binary_logloss: 0.117582
# [330]	valid_0's binary_logloss: 0.117409
# [331]	valid_0's binary_logloss: 0.117228
# [332]	valid_0's binary_logloss: 0.117108
# [333]	valid_0's binary_logloss: 0.116812
# [334]	valid_0's binary_logloss: 0.116637
# [335]	valid_0's binary_logloss: 0.116465
# [336]	valid_0's binary_logloss: 0.116349
# [337]	valid_0's binary_logloss: 0.116215
# [338]	valid_0's binary_logloss: 0.116091
# [339]	valid_0's binary_logloss: 0.115944
# [340]	valid_0's binary_logloss: 0.115827
# [341]	valid_0's binary_logloss: 0.115633
# [342]	valid_0's binary_logloss: 0.115436
# [343]	valid_0's binary_logloss: 0.115218
# [344]	valid_0's binary_logloss: 0.115133
# [345]	valid_0's binary_logloss: 0.114986
# [346]	valid_0's binary_logloss: 0.114875
# [347]	valid_0's binary_logloss: 0.114715
# [348]	valid_0's binary_logloss: 0.114513
# [349]	valid_0's binary_logloss: 0.114342
# [350]	valid_0's binary_logloss: 0.114239
# [351]	valid_0's binary_logloss: 0.114172
# [352]	valid_0's binary_logloss: 0.114023
# [353]	valid_0's binary_logloss: 0.113866
# [354]	valid_0's binary_logloss: 0.113752
# [355]	valid_0's binary_logloss: 0.113572
# [356]	valid_0's binary_logloss: 0.113341
# [357]	valid_0's binary_logloss: 0.113211
# [358]	valid_0's binary_logloss: 0.113033
# [359]	valid_0's binary_logloss: 0.112922
# [360]	valid_0's binary_logloss: 0.112756
# [361]	valid_0's binary_logloss: 0.112564
# [362]	valid_0's binary_logloss: 0.112455
# [363]	valid_0's binary_logloss: 0.112312
# [364]	valid_0's binary_logloss: 0.1122
# [365]	valid_0's binary_logloss: 0.11207
# [366]	valid_0's binary_logloss: 0.111926
# [367]	valid_0's binary_logloss: 0.111787
# [368]	valid_0's binary_logloss: 0.111687
# [369]	valid_0's binary_logloss: 0.111552
# [370]	valid_0's binary_logloss: 0.11143
# [371]	valid_0's binary_logloss: 0.11126
# [372]	valid_0's binary_logloss: 0.111196
# [373]	valid_0's binary_logloss: 0.111037
# [374]	valid_0's binary_logloss: 0.110935
# [375]	valid_0's binary_logloss: 0.110825
# [376]	valid_0's binary_logloss: 0.110608
# [377]	valid_0's binary_logloss: 0.110472
# [378]	valid_0's binary_logloss: 0.11034
# [379]	valid_0's binary_logloss: 0.110243
# [380]	valid_0's binary_logloss: 0.110054
# [381]	valid_0's binary_logloss: 0.109785
# [382]	valid_0's binary_logloss: 0.109646
# [383]	valid_0's binary_logloss: 0.109459
# [384]	valid_0's binary_logloss: 0.109294
# [385]	valid_0's binary_logloss: 0.109147
# [386]	valid_0's binary_logloss: 0.109034
# [387]	valid_0's binary_logloss: 0.108953
# [388]	valid_0's binary_logloss: 0.108787
# [389]	valid_0's binary_logloss: 0.10863
# [390]	valid_0's binary_logloss: 0.108527
# [391]	valid_0's binary_logloss: 0.108405
# [392]	valid_0's binary_logloss: 0.108264
# [393]	valid_0's binary_logloss: 0.108109
# [394]	valid_0's binary_logloss: 0.107934
# [395]	valid_0's binary_logloss: 0.107756
# [396]	valid_0's binary_logloss: 0.107633
# [397]	valid_0's binary_logloss: 0.107476
# [398]	valid_0's binary_logloss: 0.10731
# [399]	valid_0's binary_logloss: 0.107267
# [400]	valid_0's binary_logloss: 0.107152
# LGBMClassifier(n_estimators=400, random_state=20)

# %%
def get_eval_score(y_test, y_pred, y_pred_proba):
    from sklearn.metrics import f1_score, roc_auc_score, confusion_matrix,accuracy_score, precision_score, recall_score
    confusion = confusion_matrix(y_test, y_pred)
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_pred_proba)
    
    print("-"* 100)
    print("오차행렬:")
    print(confusion)
    print("정확도: {:.7f} 정밀도: {:.7f} 재현율: {:.7f} F1:{:.7f} AUC: {:.7f}".\
          format(acc, prec,recall, f1, roc_auc ))
    return

# %%
get_eval_score(y_train, lgbm.predict(X_train), lgbm.predict_proba(X_train)[:,-1])
get_eval_score(y_test, lgbm.predict(X_test), lgbm.predict_proba(X_test)[:,-1])
# Out:
# ----------------------------------------------------------------------------------------------------
# 오차행렬:
# [[44539  1358]
#  [  137 45760]]
# 정확도: 0.9837135 정밀도: 0.9711787 재현율: 0.9970151 F1:0.9839273 AUC: 0.9989899
# ----------------------------------------------------------------------------------------------------
# 오차행렬:
# [[14282  1017]
#  [  157 15142]]
# 정확도: 0.9616315 정밀도: 0.9370629 재현율: 0.9897379 F1:0.9626804 AUC: 0.9935473
